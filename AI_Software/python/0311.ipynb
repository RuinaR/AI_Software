# %%
a = 10
print(a)
# Out:
# 10

# %%
if True:
    print(a);
    print(a);
# Out:
# 10
# 10

# %%
def function(num):
    '''2배로 만드는 함수'''

    result = num * 2
    return result

print(function.__doc__)

print(function(3))
# Out:
# 2배로 만드는 함수
# 6
